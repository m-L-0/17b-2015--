# %%
import tensorflow as tf  
import numpy as np  
import glob  
import random  
from PIL import Image   
import configparser  
import os  

IMAGE_HEIGHT = 36  
IMAGE_WIDTH = 48  
MAX_CAPTCHA = 4 
CHAR_SET_LEN = 11 


####################################################################  
#读热编码
def Onehot(text):
    vector = list()
    lentext = len(text)
    for i in range(lentext):
         vector.append(np.zeros(4 * 11))
    for i,s in enumerate(text):
        s = str(s)
        for index,n in enumerate (s):
            vector[i][(index)*11+int(n)] = 1
        if index < 4:
            for m in range(index+1,4):
                vector[i][(m)*11+10] = 1
                
    
    return vector


# 定义CNN  
def crack_captcha_cnn(X, keep_prob, w_alpha=0.01, b_alpha=0.1):  
    x = tf.reshape(X, shape=[-1, IMAGE_HEIGHT, IMAGE_WIDTH, 1])  
    # print(x.get_shape())  

    # w_c1_alpha = np.sqrt(2.0/(IMAGE_HEIGHT*IMAGE_WIDTH)) #  
    # w_c2_alpha = np.sqrt(2.0/(3*3*32))  
    # w_c3_alpha = np.sqrt(2.0/(3*3*64))  
    # w_d1_alpha = np.sqrt(2.0/(8*32*64))  
    # out_alpha = np.sqrt(2.0/1024)  

    # 3 conv layer  
    w_c1 = tf.Variable(w_alpha * tf.random_normal([3, 3, 1, 32]))  
    b_c1 = tf.Variable(b_alpha * tf.random_normal([32]))  
    conv1 = tf.nn.relu(tf.nn.bias_add(tf.nn.conv2d(x, w_c1, strides=[1, 1, 1, 1], padding='VALID'), b_c1))  
    conv1 = tf.nn.max_pool(conv1, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='SAME')  
    conv1 = tf.nn.dropout(conv1, keep_prob)  
    # print(conv1.get_shape())  

    w_c2 = tf.Variable(w_alpha * tf.random_normal([3, 3, 32, 64]))  
    b_c2 = tf.Variable(b_alpha * tf.random_normal([64]))  
    conv2 = tf.nn.relu(tf.nn.bias_add(tf.nn.conv2d(conv1, w_c2, strides=[1, 1, 1, 1], padding='VALID'), b_c2))  
    conv2 = tf.nn.max_pool(conv2, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='SAME')  
    conv2 = tf.nn.dropout(conv2, keep_prob)  
    # print(conv2.get_shape())  

    w_c3 = tf.Variable(w_alpha * tf.random_normal([3, 3, 64, 64]))  
    b_c3 = tf.Variable(b_alpha * tf.random_normal([64]))  
    conv3 = tf.nn.relu(tf.nn.bias_add(tf.nn.conv2d(conv2, w_c3, strides=[1, 1, 1, 1], padding='VALID'), b_c3))  
    conv3 = tf.nn.max_pool(conv3, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='SAME')  
    conv3 = tf.nn.dropout(conv3, keep_prob) 
    # print(conv3.get_shape())  

    # Fully connected layer  
    w_d = tf.Variable(w_alpha * tf.random_normal([3*5*64, 1024]))  
    b_d = tf.Variable(b_alpha * tf.random_normal([1024]))  
    dense = tf.reshape(conv3, [-1, w_d.get_shape().as_list()[0]])  
    dense = tf.nn.relu(tf.add(tf.matmul(dense, w_d), b_d))  
    dense = tf.nn.dropout(dense, keep_prob)  

    w_out = tf.Variable(w_alpha * tf.random_normal([1024, MAX_CAPTCHA * CHAR_SET_LEN]))  
    b_out = tf.Variable(b_alpha * tf.random_normal([MAX_CAPTCHA * CHAR_SET_LEN]))  
    out = tf.add(tf.matmul(dense, w_out), b_out)  
    # out = tf.nn.softmax(out)  
    return out

# %%
def read_and_decode(filename):
    #根据文件名生成一个队列
    filename_queue = tf.train.string_input_producer([filename])

    reader = tf.TFRecordReader()
    _, serialized_example = reader.read(filename_queue)   #返回文件名和文件
    features = tf.parse_single_example(serialized_example,
                                       features={
                                           'label': tf.FixedLenFeature([], tf.int64),
                                           'img_raw' : tf.FixedLenFeature([], tf.string),
                                       })

    img = tf.decode_raw(features['img_raw'], tf.uint8)
    img = tf.cast(img,tf.float64)

    img = tf.reshape(img, [36, 48, 1])
#     img = tf.split(img,3,2)[0]
    label = tf.cast(features['label'], tf.int32)
    img_batch, label_batch = tf.train.shuffle_batch([img, label],
                                                batch_size=64, capacity=2000,
                                                min_after_dequeue=1000)
    return img_batch,label_batch

# %%
# 训练  
def train_crack_captcha_cnn():  
    X = tf.placeholder(tf.float32, [None, IMAGE_HEIGHT , IMAGE_WIDTH,1])  
    Y = tf.placeholder(tf.float32, [None, MAX_CAPTCHA * CHAR_SET_LEN])  
    keep_prob = tf.placeholder(tf.float32)  # dropout  
    output = crack_captcha_cnn(X, keep_prob)  
    # loss  
    # loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(output, Y))  
    loss = 0
    for i in range(4):
        loss = loss + ((0.25)*tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits( labels=predictY[:,i], logits=predicty[:,i])))  
    # 最后一层用来分类的softmax和sigmoid有什么不同？  
    # optimizer 为了加快训练 learning_rate应该开始大，然后慢慢衰  
    optimizer = tf.train.AdamOptimizer(learning_rate=0.0001).minimize(loss)  

    predict = tf.reshape(output, [-1, MAX_CAPTCHA, CHAR_SET_LEN])  
    max_idx_p = tf.argmax(predict, 2)  
    max_idx_l = tf.argmax(tf.reshape(Y, [-1, MAX_CAPTCHA, CHAR_SET_LEN]), 2)  
    correct_pred = tf.equal(max_idx_p, max_idx_l)  
    accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))  
    saver = tf.train.Saver()#保存模型 
    max_acc = 1
    batch_1x, batch_1y = read_and_decode("train_1.tfrecord")
    batch_2x, batch_2y = read_and_decode("train_2.tfrecord")
    batch_3x, batch_3y = read_and_decode("train_3.tfrecord")
    batch_4x, batch_4y = read_and_decode("train_4.tfrecord")
    batch_5x, batch_5y = read_and_decode("train_5.tfrecord")
    batch_6x, batch_6y = read_and_decode("train_6.tfrecord")
    batch_7x, batch_7y = read_and_decode("train_7.tfrecord")
    batch_8x, batch_8y = read_and_decode("train_8.tfrecord")
     
    batch_x_v, batch_y_v = read_and_decode("validation.tfrecord")
    
    with tf.Session() as sess:  
        sess.run(tf.global_variables_initializer())  
        coord = tf.train.Coordinator()
        threads = tf.train.start_queue_runners(sess=sess, coord=coord)
        
        
        for i in range(3200):
            if i<400:
                val, l = sess.run([batch_1x,batch_1y])
            elif i<800:
                val, l = sess.run([batch_2x,batch_2y])
            elif i<1200:
                val, l = sess.run([batch_3x,batch_3y])
            elif i<1600:
                val, l = sess.run([batch_4x,batch_4y])
            elif i<2000:
                val, l = sess.run([batch_5x,batch_5y])
            elif i<2400:
                val, l = sess.run([batch_6x,batch_6y])
            elif i<2800:
                val, l = sess.run([batch_7x,batch_7y])
            elif i<3200:
                val, l = sess.run([batch_8x,batch_8y])
                
            l = Onehot(l)
            acc = sess.run(accuracy, feed_dict={X: val, Y: l, keep_prob: 0.7})
            if i%10 == 0:
                print("step is:" + str(i), "acc is :" + str(acc))  
            
            if i % 50 == 0:  
                val_v,l_v =sess.run([batch_x_v,batch_y_v])
                l_v = Onehot(l_v)
                _, lossSize = sess.run([optimizer, loss], feed_dict={X: val_v, Y: l_v, keep_prob: 1.0})
                print("step is:" + str(i), u"损失函数大小为" + str(lossSize))  
                
                if abs(lossSize) < max_acc:
                    max_acc = abs(lossSize)
                    saver.save(sess,'model/mnist.ckpt')

        coord.request_stop()
        coord.join(threads)

if __name__ == '__main__':  
    train_crack_captcha_cnn()
# Out:
# step is:0 acc is :0.0898438
# step is:0 损失函数大小为0.749354
# step is:10 acc is :0.179688
# step is:20 acc is :0.183594
# step is:30 acc is :0.179688
# step is:40 acc is :0.21875
# step is:50 acc is :0.179688
# step is:50 损失函数大小为0.747158
# step is:60 acc is :0.238281
# step is:70 acc is :0.25
# step is:80 acc is :0.222656
# step is:90 acc is :0.234375
# step is:100 acc is :0.25
# step is:100 损失函数大小为0.745407
# step is:110 acc is :0.25
# step is:120 acc is :0.257812
# step is:130 acc is :0.242188
# step is:140 acc is :0.257812
# step is:150 acc is :0.257812
# step is:150 损失函数大小为0.743023
# step is:160 acc is :0.296875
# step is:170 acc is :0.253906
# step is:180 acc is :0.3125
# step is:190 acc is :0.285156
# step is:200 acc is :0.28125
# step is:200 损失函数大小为0.739637
# step is:210 acc is :0.28125
# step is:220 acc is :0.3125
# step is:230 acc is :0.328125
# step is:240 acc is :0.308594
# step is:250 acc is :0.335938
# step is:250 损失函数大小为0.736412
# step is:260 acc is :0.308594
# step is:270 acc is :0.355469
# step is:280 acc is :0.339844
# step is:290 acc is :0.359375
# step is:300 acc is :0.328125
# step is:300 损失函数大小为0.732441
# step is:310 acc is :0.335938
# step is:320 acc is :0.332031
# step is:330 acc is :0.320312
# step is:340 acc is :0.34375
# step is:350 acc is :0.34375
# step is:350 损失函数大小为0.724838
# step is:360 acc is :0.328125
# step is:370 acc is :0.324219
# step is:380 acc is :0.359375
# step is:390 acc is :0.375
# step is:400 acc is :0.382812
# step is:400 损失函数大小为0.716731
# step is:410 acc is :0.390625
# step is:420 acc is :0.351562
# step is:430 acc is :0.335938
# step is:440 acc is :0.304688
# step is:450 acc is :0.339844
# step is:450 损失函数大小为0.707771
# step is:460 acc is :0.332031
# step is:470 acc is :0.34375
# step is:480 acc is :0.375
# step is:490 acc is :0.320312
# step is:500 acc is :0.363281
# step is:500 损失函数大小为0.698326
# step is:510 acc is :0.359375
# step is:520 acc is :0.328125
# step is:530 acc is :0.339844
# step is:540 acc is :0.335938
# step is:550 acc is :0.347656
# step is:550 损失函数大小为0.680742
# step is:560 acc is :0.324219
# step is:570 acc is :0.402344
# step is:580 acc is :0.394531
# step is:590 acc is :0.378906
# step is:600 acc is :0.414062
# step is:600 损失函数大小为0.663578
# step is:610 acc is :0.417969
# step is:620 acc is :0.363281
# step is:630 acc is :0.300781
# step is:640 acc is :0.324219
# step is:650 acc is :0.359375
# step is:650 损失函数大小为0.640311
# step is:660 acc is :0.363281
# step is:670 acc is :0.347656
# step is:680 acc is :0.335938
# step is:690 acc is :0.421875
# step is:700 acc is :0.316406
# step is:700 损失函数大小为0.609827
# step is:710 acc is :0.339844
# step is:720 acc is :0.335938
# step is:730 acc is :0.394531
# step is:740 acc is :0.347656
# step is:750 acc is :0.351562
# step is:750 损失函数大小为0.569855
# step is:760 acc is :0.367188
# step is:770 acc is :0.34375
# step is:780 acc is :0.335938
# step is:790 acc is :0.328125
# step is:800 acc is :0.34375
# step is:800 损失函数大小为0.531788
# step is:810 acc is :0.382812
# step is:820 acc is :0.359375
# step is:830 acc is :0.367188
# step is:840 acc is :0.378906
# step is:850 acc is :0.355469
# step is:850 损失函数大小为0.471753
# step is:860 acc is :0.304688
# step is:870 acc is :0.410156
# step is:880 acc is :0.386719
# step is:890 acc is :0.332031
# step is:900 acc is :0.402344
# step is:900 损失函数大小为0.424734
# step is:910 acc is :0.363281
# step is:920 acc is :0.394531
# step is:930 acc is :0.355469
# step is:940 acc is :0.398438
# step is:950 acc is :0.382812
# step is:950 损失函数大小为0.322244
# step is:960 acc is :0.339844
# step is:970 acc is :0.390625
# step is:980 acc is :0.394531
# step is:990 acc is :0.328125
# step is:1000 acc is :0.359375
# step is:1000 损失函数大小为0.251254
# INFO:tensorflow:Error reported to Coordinator: <class 'tensorflow.python.framework.errors_impl.CancelledError'>, Enqueue operation was cancelled
# 	 [[Node: input_producer_2/input_producer_2_EnqueueMany = QueueEnqueueManyV2[Tcomponents=[DT_STRING], timeout_ms=-1, _device="/job:localhost/replica:0/task:0/cpu:0"](input_producer_2, input_producer_2/RandomShuffle)]]
#
# Caused by op 'input_producer_2/input_producer_2_EnqueueMany', defined at:
#   File "/home/haiyang/.linuxbrew/Cellar/python3/3.6.0/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/home/haiyang/.linuxbrew/Cellar/python3/3.6.0/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/home/haiyang/venv/lib/python3.6/site-packages/ipykernel/__main__.py", line 3, in <module>
#     app.launch_new_instance()
#   File "/home/haiyang/venv/lib/python3.6/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/home/haiyang/venv/lib/python3.6/site-packages/ipykernel/kernelapp.py", line 474, in start
#     ioloop.IOLoop.instance().start()
#   File "/home/haiyang/venv/lib/python3.6/site-packages/zmq/eventloop/ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "/home/haiyang/venv/lib/python3.6/site-packages/tornado/ioloop.py", line 887, in start
#     handler_func(fd_obj, events)
#   File "/home/haiyang/venv/lib/python3.6/site-packages/tornado/stack_context.py", line 275, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home/haiyang/venv/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "/home/haiyang/venv/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/home/haiyang/venv/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "/home/haiyang/venv/lib/python3.6/site-packages/tornado/stack_context.py", line 275, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home/haiyang/venv/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 276, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/home/haiyang/venv/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 228, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/home/haiyang/venv/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 390, in execute_request
#     user_expressions, allow_stdin)
#   File "/home/haiyang/venv/lib/python3.6/site-packages/ipykernel/ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/home/haiyang/venv/lib/python3.6/site-packages/ipykernel/zmqshell.py", line 501, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/home/haiyang/venv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2717, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/home/haiyang/venv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2821, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/home/haiyang/venv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2881, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-3-492e803514d0>", line 75, in <module>
#     train_crack_captcha_cnn()
#   File "<ipython-input-3-492e803514d0>", line 23, in train_crack_captcha_cnn
#     batch_3x, batch_3y = read_and_decode("train_3.tfrecord")
#   File "<ipython-input-2-6c7daaa3c46d>", line 4, in read_and_decode
#     filename_queue = tf.train.string_input_producer([filename])
#   File "/home/haiyang/venv/lib/python3.6/site-packages/tensorflow/python/training/input.py", line 230, in string_input_producer
#     cancel_op=cancel_op)
#   File "/home/haiyang/venv/lib/python3.6/site-packages/tensorflow/python/training/input.py", line 162, in input_producer
#     enq = q.enqueue_many([input_tensor])
#   File "/home/haiyang/venv/lib/python3.6/site-packages/tensorflow/python/ops/data_flow_ops.py", line 367, in enqueue_many
#     self._queue_ref, vals, name=scope)
#   File "/home/haiyang/venv/lib/python3.6/site-packages/tensorflow/python/ops/gen_data_flow_ops.py", line 1538, in _queue_enqueue_many_v2
#     name=name)
#   File "/home/haiyang/venv/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py", line 763, in apply_op
#     op_def=op_def)
#   File "/home/haiyang/venv/lib/python3.6/site-packages/tensorflow/python/framework/ops.py", line 2327, in create_op
#     original_op=self._default_original_op, op_def=op_def)
#   File "/home/haiyang/venv/lib/python3.6/site-packages/tensorflow/python/framework/ops.py", line 1226, in __init__
#     self._traceback = _extract_stack()
#
# CancelledError (see above for traceback): Enqueue operation was cancelled
# 	 [[Node: input_producer_2/input_producer_2_EnqueueMany = QueueEnqueueManyV2[Tcomponents=[DT_STRING], timeout_ms=-1, _device="/job:localhost/replica:0/task:0/cpu:0"](input_producer_2, input_producer_2/RandomShuffle)]]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-492e803514d0> in <module>()
#      73
#      74 if __name__ == '__main__':
# ---> 75     train_crack_captcha_cnn()
#
# <ipython-input-3-492e803514d0> in train_crack_captcha_cnn()
#      55
#      56             l = Onehot(l)
# ---> 57             acc = sess.run(accuracy, feed_dict={X: val, Y: l, keep_prob: 0.7})
#      58             if i%10 == 0:
#      59                 print("step is:" + str(i), "acc is :" + str(acc))
#
# /home/haiyang/venv/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     765     try:
#     766       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 767                          run_metadata_ptr)
#     768       if run_metadata:
#     769         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /home/haiyang/venv/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     963     if final_fetches or final_targets:
#     964       results = self._do_run(handle, final_targets, final_fetches,
# --> 965                              feed_dict_string, options, run_metadata)
#     966     else:
#     967       results = []
#
# /home/haiyang/venv/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1013     if handle is None:
#    1014       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1015                            target_list, options, run_metadata)
#    1016     else:
#    1017       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /home/haiyang/venv/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1020   def _do_call(self, fn, *args):
#    1021     try:
# -> 1022       return fn(*args)
#    1023     except errors.OpError as e:
#    1024       message = compat.as_text(e.message)
#
# /home/haiyang/venv/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1002         return tf_session.TF_Run(session, options,
#    1003                                  feed_dict, fetch_list, target_list,
# -> 1004                                  status, run_metadata)
#    1005
#    1006     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
#测试
def test_crack_captcha_cnn():  
    X = tf.placeholder(tf.float32, [None, IMAGE_HEIGHT , IMAGE_WIDTH,1])  
    Y = tf.placeholder(tf.float32, [None, MAX_CAPTCHA * CHAR_SET_LEN])  
    keep_prob = tf.placeholder(tf.float32)  # dropout  
    output = crack_captcha_cnn(X, keep_prob)  
    predict = tf.reshape(output, [-1, MAX_CAPTCHA, CHAR_SET_LEN])  
    max_idx_p = tf.argmax(predict, 2)  
    max_idx_l = tf.argmax(tf.reshape(Y, [-1, MAX_CAPTCHA, CHAR_SET_LEN]), 2)  
    correct_pred = tf.equal(max_idx_p, max_idx_l)  
    accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))  
    saver = tf.train.Saver()#保存模型 
    
    batch_x_t, batch_y_t = read_and_decode("test.tfrecord")
    print(batch_x_t)
    with tf.Session() as sess:
        sess.run(tf.global_variables_initializer())  
        coord = tf.train.Coordinator()
        threads = tf.train.start_queue_runners(sess=sess, coord=coord)
        #saver.restore(sess, tf.train.latest_checkpoint('./model/'))
        saver.restore(sess, tf.train.latest_checkpoint('model/'))
        
        for i in range(40):  
            x_t, y_t = sess.run([batch_x_t,batch_y_t])
            y_t = Onehot(y_t)
            acc = sess.run(accuracy, feed_dict={X: x_t, Y: y_t, keep_prob: 0.7})
            print("step is:" + str(i), "acc is :" + str(acc))  
        coord.request_stop()
        coord.join(threads)


if __name__ == '__main__':  
    test_crack_captcha_cnn()
# Out:
# Tensor("dropout_14/mul:0", shape=(?, 3, 5, 64), dtype=float32)
# Tensor("shuffle_batch_27:0", shape=(64, 36, 48, 1), dtype=float64)
# INFO:tensorflow:Error reported to Coordinator: <class 'RuntimeError'>, Attempted to use a closed Session.
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# /home/haiyang/venv/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1021     try:
# -> 1022       return fn(*args)
#    1023     except errors.OpError as e:
#
# /home/haiyang/venv/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1003                                  feed_dict, fetch_list, target_list,
# -> 1004                                  status, run_metadata)
#    1005
#
# /home/haiyang/.linuxbrew/Cellar/python3/3.6.0/lib/python3.6/contextlib.py in __exit__(self, type, value, traceback)
#      88             try:
# ---> 89                 next(self.gen)
#      90             except StopIteration:
#
# /home/haiyang/venv/lib/python3.6/site-packages/tensorflow/python/framework/errors_impl.py in raise_exception_on_not_ok_status()
#     465           compat.as_text(pywrap_tensorflow.TF_Message(status)),
# --> 466           pywrap_tensorflow.TF_GetCode(status))
#     467   finally:
#
# NotFoundError: Key Variable_30 not found in checkpoint
# 	 [[Node: save_3/RestoreV2_72 = RestoreV2[dtypes=[DT_FLOAT], _device="/job:localhost/replica:0/task:0/cpu:0"](_recv_save_3/Const_0, save_3/RestoreV2_72/tensor_names, save_3/RestoreV2_72/shape_and_slices)]]
#
# During handling of the above exception, another exception occurred:
#
# NotFoundError                             Traceback (most recent call last)
# <ipython-input-6-6726d409306c> in <module>()
#      31
#      32 if __name__ == '__main__':
# ---> 33     test_crack_captcha_cnn()
#      34
#      35
#
# <ipython-input-6-6726d409306c> in test_crack_captcha_cnn()
#      19         threads = tf.train.start_queue_runners(sess=sess, coord=coord)
#      20         #saver.restore(sess, tf.train.latest_checkpoint('./model/'))
# ---> 21         saver.restore(sess, tf.train.latest_checkpoint('model/'))
#      22
#      23         for i in range(40):
#
# /home/haiyang/venv/lib/python3.6/site-packages/tensorflow/python/training/saver.py in restore(self, sess, save_path)
#    1426       return
#    1427     sess.run(self.saver_def.restore_op_name,
# -> 1428              {self.saver_def.filename_tensor_name: save_path})
#    1429
#    1430   @staticmethod
#
# /home/haiyang/venv/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     765     try:
#     766       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 767                          run_metadata_ptr)
#     768       if run_metadata:
#     769         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /home/haiyang/venv/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     963     if final_fetches or final_targets:
#     964       results = self._do_run(handle, final_targets, final_fetches,
# --> 965                              feed_dict_string, options, run_metadata)
#     966     else:
#     967       results = []
#
# /home/haiyang/venv/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1013     if handle is None:
#    1014       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1015                            target_list, options, run_metadata)
#    1016     else:
#    1017       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /home/haiyang/venv/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1033         except KeyError:
#    1034           pass
# -> 1035       raise type(e)(node_def, op, message)
#    1036
#    1037   def _extend_graph(self):
#
# NotFoundError: Key Variable_30 not found in checkpoint
# 	 [[Node: save_3/RestoreV2_72 = RestoreV2[dtypes=[DT_FLOAT], _device="/job:localhost/replica:0/task:0/cpu:0"](_recv_save_3/Const_0, save_3/RestoreV2_72/tensor_names, save_3/RestoreV2_72/shape_and_slices)]]
#
# Caused by op 'save_3/RestoreV2_72', defined at:
#   File "/home/haiyang/.linuxbrew/Cellar/python3/3.6.0/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/home/haiyang/.linuxbrew/Cellar/python3/3.6.0/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/home/haiyang/venv/lib/python3.6/site-packages/ipykernel/__main__.py", line 3, in <module>
#     app.launch_new_instance()
#   File "/home/haiyang/venv/lib/python3.6/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/home/haiyang/venv/lib/python3.6/site-packages/ipykernel/kernelapp.py", line 474, in start
#     ioloop.IOLoop.instance().start()
#   File "/home/haiyang/venv/lib/python3.6/site-packages/zmq/eventloop/ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "/home/haiyang/venv/lib/python3.6/site-packages/tornado/ioloop.py", line 887, in start
#     handler_func(fd_obj, events)
#   File "/home/haiyang/venv/lib/python3.6/site-packages/tornado/stack_context.py", line 275, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home/haiyang/venv/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "/home/haiyang/venv/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/home/haiyang/venv/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "/home/haiyang/venv/lib/python3.6/site-packages/tornado/stack_context.py", line 275, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home/haiyang/venv/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 276, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/home/haiyang/venv/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 228, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/home/haiyang/venv/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 390, in execute_request
#     user_expressions, allow_stdin)
#   File "/home/haiyang/venv/lib/python3.6/site-packages/ipykernel/ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/home/haiyang/venv/lib/python3.6/site-packages/ipykernel/zmqshell.py", line 501, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/home/haiyang/venv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2717, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/home/haiyang/venv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2821, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/home/haiyang/venv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2881, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-6-6726d409306c>", line 33, in <module>
#     test_crack_captcha_cnn()
#   File "<ipython-input-6-6726d409306c>", line 12, in test_crack_captcha_cnn
#     saver = tf.train.Saver()#保存模型
#   File "/home/haiyang/venv/lib/python3.6/site-packages/tensorflow/python/training/saver.py", line 1040, in __init__
#     self.build()
#   File "/home/haiyang/venv/lib/python3.6/site-packages/tensorflow/python/training/saver.py", line 1070, in build
#     restore_sequentially=self._restore_sequentially)
#   File "/home/haiyang/venv/lib/python3.6/site-packages/tensorflow/python/training/saver.py", line 675, in build
#     restore_sequentially, reshape)
#   File "/home/haiyang/venv/lib/python3.6/site-packages/tensorflow/python/training/saver.py", line 402, in _AddRestoreOps
#     tensors = self.restore_op(filename_tensor, saveable, preferred_shard)
#   File "/home/haiyang/venv/lib/python3.6/site-packages/tensorflow/python/training/saver.py", line 242, in restore_op
#     [spec.tensor.dtype])[0])
#   File "/home/haiyang/venv/lib/python3.6/site-packages/tensorflow/python/ops/gen_io_ops.py", line 668, in restore_v2
#     dtypes=dtypes, name=name)
#   File "/home/haiyang/venv/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py", line 763, in apply_op
#     op_def=op_def)
#   File "/home/haiyang/venv/lib/python3.6/site-packages/tensorflow/python/framework/ops.py", line 2327, in create_op
#     original_op=self._default_original_op, op_def=op_def)
#   File "/home/haiyang/venv/lib/python3.6/site-packages/tensorflow/python/framework/ops.py", line 1226, in __init__
#     self._traceback = _extract_stack()
#
# NotFoundError (see above for traceback): Key Variable_30 not found in checkpoint
# 	 [[Node: save_3/RestoreV2_72 = RestoreV2[dtypes=[DT_FLOAT], _device="/job:localhost/replica:0/task:0/cpu:0"](_recv_save_3/Const_0, save_3/RestoreV2_72/tensor_names, save_3/RestoreV2_72/shape_and_slices)]]
